# %% [markdown]
# ### Ways to Import

# %%
# import math
# print(math.pi)

# import math as mono
# print(mono.pi)

# from math import pi
# print(pi)

# from math import pi, sin
# print(sin(pi/2))

# from math import *
# print(pi) # avoid
# Out:
# 1.0

# %% [markdown]
# ### Lambda Function

# %%
# def func(x):
#     #body
#     return x*x

# print(func(4))

var = lambda x,y : x+y
print(var(5, 10))
# func = lambda x: x*x
# print(func(4))
# Out:
# 15

# %% [markdown]
# ### Enumerate

# %%
# enumerate
var = [10,5,14,2,168,79,14]
var_enum = enumerate(var)
var_dict = dict(var_enum)
print(var_enum)
print(var_dict)
# Out:
# ...
# {0: 10, 1: 5, 2: 14, 3: 2, 4: 168, 5: 79, 6: 14}

# %% [markdown]
# ### Counter

# %%
# Counter
from collections import Counter
var_count = Counter(var)
print(var_count)
# Out:
# Counter({14: 2, 10: 1, 5: 1, 2: 1, 168: 1, 79: 1})

# %% [markdown]
# ### Matplotlib

# %%
def normal_pdf(x, mu=0, sigma=1):
 sqrt_two_pi = math.sqrt(2 * math.pi)
 return (math.exp(-(x-mu) ** 2 / 2 / sigma ** 2) / (sqrt_two_pi * sigma))

xs = [x / 10.0 for x in range(-50, 50)]
plt.plot(xs,[normal_pdf(x,sigma=1) for x in xs],'-',label='mu=0,sigma=1')
plt.plot(xs,[normal_pdf(x,sigma=2) for x in xs],'--',label='mu=3,sigma=2')
plt.plot(xs,[normal_pdf(x,mu=-2, sigma=5) for x in xs],'-.',label='mu=-1,sigma=1')
plt.legend()
plt.title("Various Normal pdfs")
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
sub = ['CA-708', 'CA-406', 'MTH-401CA', 'CA-402', 'CA-403', 'CA-404', 'CA-405']
sub_num = [x+1 for x, _ in enumerate(sub)]
marks = [9, 10, 10, 9, 8, 9, 9]
grade = ('C','B', 'B+', 'A', 'A+')
grade2 = [x for x in range(6,11)]
plt.xticks(sub_num, sub)
plt.yticks(grade2, grade)
plt.bar(sub_num, marks, width=0.4)
plt.show()

# %%
sub = ['CA-708', 'CA-406', 'MTH-401CA', 'CA-402', 'CA-403', 'CA-404', 'CA-405']
sub_num = [x+1 for x, _ in enumerate(sub)]
marks = [9, 10, 10, 9, 8, 9, 9]
grade = (['A', 'A+', 'A+', 'A', 'B+', 'A', 'A'])
fig, ax = plt.subplots()

plt.ylim(0,15)
plt.xticks(sub_num, sub, rotation=45)
plt.scatter(sub_num, marks)
for idx, label in enumerate(grade):
    ax.annotate(label, (sub_num[idx]+0.1, marks[idx]+0.1))
plt.show()

# %% [markdown]
# ### Cleaning

# %%
def f(x):
    try: 
        x = float(x)
        return x
    except:
        return None

print(f("reege"))
# Out:
# None

# %% [markdown]
# ### Manipulating data

# %%
import datetime
data = [
    {'closing_price': 102.06,'date': datetime.datetime(2014, 8, 29, 0, 0), 'symbol': 'AAPL'},
    {'closing_price': 103.06,'date': datetime.datetime(2014, 8, 29, 0, 0), 'symbol': 'AAPL'},
    {'closing_price': 104.06,'date': datetime.datetime(2014, 8, 29, 0, 0), 'symbol': 'ABCD'},
    {'closing_price': 105.06,'date': datetime.datetime(2014, 8, 29, 0, 0), 'symbol': 'AAPL'},
    {'closing_price': 106.06,'date': datetime.datetime(2014, 8, 29, 0, 0), 'symbol': 'ABCD'},
]
max_aapl_price = max(item["closing_price"] for item in data if item["symbol"] == "AAPL")
print(max_aapl_price)
# Out:
# 105.06

# %%
def distance(v, w):
    x1, y1 = v[0], v[1]    
    x2, y2 = v[0], v[1]
    return math.sqrt((x1-x2)**2 + (y1-y2)**2)


def majority_vote(labels):
    vote_counts = Counter(labels)
    winner, winner_count = vote_counts.most_common(1)[0]
    num_winners = len([count for count in vote_counts.values() if count == winner_count])
    if num_winners == 1:
        return winner # unique winner, so return it
    else:
        return majority_vote(labels[:-1])
    
    
def knn_classify(k, labeled_points, new_point):
    by_distance = sorted(labeled_points, key = lambda (point, _): distance(point, new_point))
    k_nearest_labels = [label for _, label in by_distance[:k]]
    return majority_vote(k_nearest_labels)

print(knn_classify(5, [[[1,2], 'A'],[[1,2], 'A'],[[1,2], 'A'],[[1,2], 'A'],[[1,3], 'B']], [1,3]))
# Out:
#   Input In [57]
#     by_distance = sorted(labeled_points, key = lambda (point, _): distance(point, new_point))
#                                                       ^
# SyntaxError: invalid syntax

# %%
row  = float(row)

# %%
list1 = ('apple', 'grapes', 'mango')
list2 = ('mono', 'light', 'monolight')
x = zip(list1, list2)
x = tuple(x)

# %%
print(tuple(x))
# Out:
# (('apple', 'mono'), ('grapes', 'light'), ('mango', 'monolight'))

# %%
Res = [i for i, j in x]+[j for i, j in x ]
var = [i, j for i, j in x]
print(var)
print(Res)
# Out:
#   Input In [28]
#     var = [i, j for i, j in x]
#            ^
# SyntaxError: did you forget parentheses around the comprehension target?

# %%
# Out:
# /home/light/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
import turtle
import random

player_one = turtle.Turtle()
player_one.color("green")
player_one.shape("turtle")
player_one.penup()
player_one.goto(-200,100)
player_two = player_one.clone()
player_two.color("blue")
player_two.penup()
player_two.goto(-200,-100)

# %%
player_one.goto(300,60)
player_one.pendown()
player_one.circle(40)
player_one.penup()
player_one.goto(-200,100)
player_two.goto(300,-140)
player_two.pendown()
player_two.circle(40)
player_two.penup()
player_two.goto(-200,-100)

die = [1,2,3,4,5,6]

# %%
for i in range(20):
     if player_one.pos() >= (300,100):
         print("Player One Wins!")
         break
     elif player_two.pos() >= (300,-100):
         print("Player Two Wins!")
         break
     else:
         player_one_turn = input("Press 'Enter' to roll the die ")
         die_outcome = random.choice(die)
         print("The result of the die roll is: ")
         print(die_outcome)
         print("The number of steps will be: ")
         print(20*die_outcome)
         player_one.fd(20*die_outcome)
         player_two_turn = input("Press 'Enter' to roll the die ")
         die_outcome = random.choice(die)
         print("The result of the die roll is: ")
         print(die_outcome)
         print("The number of steps will be: ")
         print(20*die_outcome)
         player_two.fd(20*die_outcome)
# Out:
# Press 'Enter' to roll the die
# The result of the die roll is:
# 5
# The number of steps will be:
# 100
# Press 'Enter' to roll the die
# The result of the die roll is:
# 1
# The number of steps will be:
# 20
# Press 'Enter' to roll the die
# The result of the die roll is:
# 5
# The number of steps will be:
# 100
# Press 'Enter' to roll the die
# The result of the die roll is:
# 1
# The number of steps will be:
# 20
# Press 'Enter' to roll the die
# The result of the die roll is:
# 3
# The number of steps will be:
# 60
# Press 'Enter' to roll the die
# The result of the die roll is:
# 4
# The number of steps will be:
# 80
# Press 'Enter' to roll the die
# The result of the die roll is:
# 3
# The number of steps will be:
# 60
# Press 'Enter' to roll the die
# The result of the die roll is:
# 4
# The number of steps will be:
# 80
# Press 'Enter' to roll the die
# The result of the die roll is:
# 3
# The number of steps will be:
# 60
# Press 'Enter' to roll the die
# ...
